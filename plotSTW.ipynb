# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import ticker
#from functional import *
import h5py

# %%
oldE = np.loadtxt("oldscf_elec.dat", dtype=None)
newE = np.loadtxt("newscf_elec.dat", dtype=None)
oldP = np.loadtxt("oldscf_prot.dat", dtype=None)
newP = np.loadtxt("newscf_prot.dat", dtype=None)

oldE[:,1] -= -112.1386996454431 
oldP[:,1] -= -112.1386996454431
newE[:,1] -= -112.1386996454429 
newP[:,1] -= -112.1386996454429

# %%
oldE1 = oldE[0:25]
oldE2 = oldE[25:49]
oldE3 = oldE[49:70]
oldE4 = oldE[70:87]
oldE5 = oldE[87:101]
oldE6 = oldE[101:111]
oldE7 = oldE[111:118]

oldP1 = oldP[0:271]
oldP2 = oldP[271:470]
oldP3 = oldP[470:635]
oldP4 = oldP[635:757]
oldP5 = oldP[757:841]
oldP6 = oldP[841:894]
oldP7 = oldP[894:919]

newE1 = newE[0:9]
newE2 = newE[9:18]
newE3 = newE[18:26]
newE4 = newE[26:33]
newE5 = newE[33:40]
newE6 = newE[40:46]
newE7 = newE[46:50]

newP1 = newP[0:127]
newP2 = newP[127:241]
newP3 = newP[241:258]
newP4 = newP[258:265]
newP5 = newP[265:270]
newP6 = newP[270:273]
newP7 = newP[273:276]

newP7
# Out:
# array([[1.00000000e+00, 1.19371180e-12],
#        [2.00000000e+00, 1.09423581e-12],
#        [3.00000000e+00, 0.00000000e+00]])

# %%
fig, ax = plt.subplots(2,7, sharex='row',sharey='row',figsize=(20,6))
fig.suptitle('NEO DIIS w/ Absolute $\Delta E$', fontsize=14, fontweight='bold')
    
# Electronic SCF
ax[0,0].scatter(oldE1[:,0],oldE1[:,1],s=2,label="No DIIS")
ax[0,0].scatter(newE1[:,0],newE1[:,1],s=2,label="DIIS")
ax[0,0].set_yscale("log")
ax[0,0].set_title("In Elec SCF #1")
ax[0,0].legend()

ax[0,1].scatter(oldE2[:,0],oldE2[:,1],s=2,label="No DIIS")
ax[0,1].scatter(newE2[:,0],newE2[:,1],s=2,label="DIIS")
ax[0,1].set_yscale("log")
ax[0,1].set_title("In Elec SCF #2")
ax[0,1].legend()

ax[0,2].scatter(oldE3[:,0],oldE3[:,1],s=2,label="No DIIS")
ax[0,2].scatter(newE3[:,0],newE3[:,1],s=2,label="DIIS")
ax[0,2].set_yscale("log")
ax[0,2].set_title("In Elec SCF #3")
ax[0,2].legend()

ax[0,3].scatter(oldE4[:,0],oldE4[:,1],s=2,label="No DIIS")
ax[0,3].scatter(newE4[:,0],newE4[:,1],s=2,label="DIIS")
ax[0,3].set_yscale("log")
ax[0,3].set_title("In Elec SCF #4")
ax[0,3].legend()

ax[0,4].scatter(oldE5[:,0],oldE5[:,1],s=2,label="No DIIS")
ax[0,4].scatter(newE5[:,0],newE5[:,1],s=2,label="DIIS")
ax[0,4].set_yscale("log")
ax[0,4].set_title("In Elec SCF #5")
ax[0,4].legend()

ax[0,5].scatter(oldE6[:,0],oldE6[:,1],s=2,label="No DIIS")
ax[0,5].scatter(newE6[:,0],newE6[:,1],s=2,label="DIIS")
ax[0,5].set_yscale("log")
ax[0,5].set_title("In Elec SCF #6")
ax[0,5].legend()

ax[0,6].scatter(oldE7[:,0],oldE7[:,1],s=2,label="No DIIS")
ax[0,6].scatter(newE7[:,0],newE7[:,1],s=2,label="DIIS")
ax[0,6].set_yscale("log")
ax[0,6].set_title("In Macro-iteraction #7")
ax[0,6].legend()


# Protonic SCF
ax[1,0].scatter(oldP1[:,0],oldP1[:,1],s=1,label="No DIIS")
ax[1,0].scatter(newP1[:,0],newP1[:,1],s=1,label="DIIS")
ax[1,0].set_yscale("log")
ax[1,0].set_title("In Prot SCF #1")
ax[1,0].legend()

ax[1,1].scatter(oldP2[:,0],oldP2[:,1],s=1,label="No DIIS")
ax[1,1].scatter(newP2[:,0],newP2[:,1],s=1,label="DIIS")
ax[1,1].set_yscale("log")
ax[1,1].set_title("In Prot SCF #2")
ax[1,1].legend()

ax[1,2].scatter(oldP3[:,0],oldP3[:,1],s=1,label="No DIIS")
ax[1,2].scatter(newP3[:,0],newP3[:,1],s=1,label="DIIS")
ax[1,2].set_yscale("log")
ax[1,2].set_title("In Prot SCF #3")
ax[1,2].legend()

ax[1,3].scatter(oldP4[:,0],oldP4[:,1],s=1,label="No DIIS")
ax[1,3].scatter(newP4[:,0],newP4[:,1],s=1,label="DIIS")
ax[1,3].set_yscale("log")
ax[1,3].set_title("In Prot SCF #4")
ax[1,3].legend()

ax[1,4].scatter(oldP5[:,0],oldP5[:,1],s=1,label="No DIIS")
ax[1,4].scatter(newP5[:,0],newP5[:,1],s=1,label="DIIS")
ax[1,4].set_yscale("log")
ax[1,4].set_title("In Prot SCF #5")
ax[1,4].legend()

ax[1,5].scatter(oldP6[:,0],oldP6[:,1],s=1,label="No DIIS")
ax[1,5].scatter(newP6[:,0],newP6[:,1],s=1,label="DIIS")
ax[1,5].set_yscale("log")
ax[1,5].set_title("In Prot SCF #6")
ax[1,5].legend()

ax[1,6].scatter(oldP7[:,0],oldP7[:,1],s=1,label="No DIIS")
ax[1,6].scatter(newP7[:,0],newP7[:,1],s=1,label="DIIS")
ax[1,6].set_yscale("log")
ax[1,6].set_title("In Prot SCF #7")
ax[1,6].legend()

fig.text(0.5, 0.001, '# of Iterations', ha='center')
fig.text(0.0001, 0.5, '$\Delta E$ Against the Final Converged Energy', va='center', rotation='vertical')

fig.set_facecolor('w')
plt.tight_layout()
plt.savefig('NEODIIS_Abs_Diff.png', dpi=300)
plt.show()

# %%
# Now Calculate the difference against the converged energy obtained from the subsystem SCF

# %%
oldE = np.loadtxt("oldscf_elec.dat", dtype=None)
newE = np.loadtxt("newscf_elec.dat", dtype=None)
oldP = np.loadtxt("oldscf_prot.dat", dtype=None)
newP = np.loadtxt("newscf_prot.dat", dtype=None)

# %%
oldE1 = oldE[0:25]
oldE2 = oldE[25:49]
oldE3 = oldE[49:70]
oldE4 = oldE[70:87]
oldE5 = oldE[87:101]
oldE6 = oldE[101:111]
oldE7 = oldE[111:118]

oldP1 = oldP[0:271]
oldP2 = oldP[271:470]
oldP3 = oldP[470:635]
oldP4 = oldP[635:757]
oldP5 = oldP[757:841]
oldP6 = oldP[841:894]
oldP7 = oldP[894:919]

newE1 = newE[0:9]
newE2 = newE[9:18]
newE3 = newE[18:26]
newE4 = newE[26:33]
newE5 = newE[33:40]
newE6 = newE[40:46]
newE7 = newE[46:50]

newP1 = newP[0:127]
newP2 = newP[127:241]
newP3 = newP[241:258]
newP4 = newP[258:265]
newP5 = newP[265:270]
newP6 = newP[270:273]
newP7 = newP[273:276]

# %%
oldE1[:,1] -= -112.1286628742584
oldE2[:,1] -= -112.1383318925790 
oldE3[:,1] -= -112.1386913630897
oldE4[:,1] -= -112.1386994780567  
oldE5[:,1] -= -112.1386996421009
oldE6[:,1] -= -112.1386996453734
oldE7[:,1] -= -112.1386996454414


oldP1[:,1] -= -112.1364690236248 
oldP2[:,1] -= -112.1386422725399
oldP3[:,1] -= -112.1386984609948
oldP4[:,1] -= -112.1386996218341
oldP5[:,1] -= -112.1386996449720
oldP6[:,1] -= -112.1386996454335
oldP7[:,1] -= -112.1386996454431 



newE1[:,1] -= -112.1286628742586
newE2[:,1] -= -112.1383318937905
newE3[:,1] -= -112.1386913632913
newE4[:,1] -= -112.1386994781910
newE5[:,1] -= -112.1386996421217
newE6[:,1] -= -112.1386996453778
newE7[:,1] -= -112.1386996454417

newP1[:,1] -= -112.1364690249809
newP2[:,1] -= -112.1386422728939 
newP3[:,1] -= -112.1386984609965
newP4[:,1] -= -112.1386996218475 
newP5[:,1] -= -112.1386996449756
newP6[:,1] -= -112.1386996454338
newP7[:,1] -= -112.1386996454429

# %%
fig, ax = plt.subplots(2,7, sharex='row',sharey='row',figsize=(20,6))
fig.suptitle('NEO DIIS w/ Relative $\Delta E$', fontsize=14, fontweight='bold')
    
# Electronic SCF
ax[0,0].scatter(oldE1[:,0],oldE1[:,1],s=2,label="No DIIS")
ax[0,0].scatter(newE1[:,0],newE1[:,1],s=2,label="DIIS")
ax[0,0].set_yscale("log")
ax[0,0].set_title("In Elec SCF #1")
ax[0,0].legend()

ax[0,1].scatter(oldE2[:,0],oldE2[:,1],s=2,label="No DIIS")
ax[0,1].scatter(newE2[:,0],newE2[:,1],s=2,label="DIIS")
ax[0,1].set_yscale("log")
ax[0,1].set_title("In Elec SCF #2")
ax[0,1].legend()

ax[0,2].scatter(oldE3[:,0],oldE3[:,1],s=2,label="No DIIS")
ax[0,2].scatter(newE3[:,0],newE3[:,1],s=2,label="DIIS")
ax[0,2].set_yscale("log")
ax[0,2].set_title("In Elec SCF #3")
ax[0,2].legend()

ax[0,3].scatter(oldE4[:,0],oldE4[:,1],s=2,label="No DIIS")
ax[0,3].scatter(newE4[:,0],newE4[:,1],s=2,label="DIIS")
ax[0,3].set_yscale("log")
ax[0,3].set_title("In Elec SCF #4")
ax[0,3].legend()

ax[0,4].scatter(oldE5[:,0],oldE5[:,1],s=2,label="No DIIS")
ax[0,4].scatter(newE5[:,0],newE5[:,1],s=2,label="DIIS")
ax[0,4].set_yscale("log")
ax[0,4].set_title("In Elec SCF #5")
ax[0,4].legend()

ax[0,5].scatter(oldE6[:,0],oldE6[:,1],s=2,label="No DIIS")
ax[0,5].scatter(newE6[:,0],newE6[:,1],s=2,label="DIIS")
ax[0,5].set_yscale("log")
ax[0,5].set_title("In Elec SCF #6")
ax[0,5].legend()

ax[0,6].scatter(oldE7[:,0],oldE7[:,1],s=2,label="No DIIS")
ax[0,6].scatter(newE7[:,0],newE7[:,1],s=2,label="DIIS")
ax[0,6].set_yscale("log")
ax[0,6].set_title("In Macro-iteraction #7")
ax[0,6].legend()


# Protonic SCF
ax[1,0].scatter(oldP1[:,0],oldP1[:,1],s=1,label="No DIIS")
ax[1,0].scatter(newP1[:,0],newP1[:,1],s=1,label="DIIS")
ax[1,0].set_yscale("log")
ax[1,0].set_title("In Prot SCF #1")
ax[1,0].legend()

ax[1,1].scatter(oldP2[:,0],oldP2[:,1],s=1,label="No DIIS")
ax[1,1].scatter(newP2[:,0],newP2[:,1],s=1,label="DIIS")
ax[1,1].set_yscale("log")
ax[1,1].set_title("In Prot SCF #2")
ax[1,1].legend()

ax[1,2].scatter(oldP3[:,0],oldP3[:,1],s=1,label="No DIIS")
ax[1,2].scatter(newP3[:,0],newP3[:,1],s=1,label="DIIS")
ax[1,2].set_yscale("log")
ax[1,2].set_title("In Prot SCF #3")
ax[1,2].legend()

ax[1,3].scatter(oldP4[:,0],oldP4[:,1],s=1,label="No DIIS")
ax[1,3].scatter(newP4[:,0],newP4[:,1],s=1,label="DIIS")
ax[1,3].set_yscale("log")
ax[1,3].set_title("In Prot SCF #4")
ax[1,3].legend()

ax[1,4].scatter(oldP5[:,0],oldP5[:,1],s=1,label="No DIIS")
ax[1,4].scatter(newP5[:,0],newP5[:,1],s=1,label="DIIS")
ax[1,4].set_yscale("log")
ax[1,4].set_title("In Prot SCF #5")
ax[1,4].legend()

ax[1,5].scatter(oldP6[:,0],oldP6[:,1],s=1,label="No DIIS")
ax[1,5].scatter(newP6[:,0],newP6[:,1],s=1,label="DIIS")
ax[1,5].set_yscale("log")
ax[1,5].set_title("In Prot SCF #6")
ax[1,5].legend()

ax[1,6].scatter(oldP7[:,0],oldP7[:,1],s=1,label="No DIIS")
ax[1,6].scatter(newP7[:,0],newP7[:,1],s=1,label="DIIS")
ax[1,6].set_yscale("log")
ax[1,6].set_title("In Prot SCF #7")
ax[1,6].legend()

fig.text(0.5, 0.001, '# of Iterations', ha='center')
fig.text(0.0001, 0.5, '$\Delta E$ Against Converged $E$ of the Current SCF', va='center', rotation='vertical')
fig.set_facecolor('w')
plt.tight_layout()
plt.savefig('NEODIIS_Rel_Diff.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, big_axes = plt.subplots( figsize=(15.0, 15.0) , nrows=2, ncols=1, sharey=True) 

for row, big_ax in enumerate(big_axes, start=1):
    big_ax.set_title("Subplot row %s \n" % row, fontsize=16)

    # Turn off axis lines and ticks of the big subplot 
    # obs alpha is 0 in RGBA string!
    big_ax.tick_params(labelcolor=(1.,1.,1., 0.0), top='off', bottom='off', left='off', right='off')
    # removes the white frame
    big_ax._frameon = False


for i in range(1,15):
    ax = fig.add_subplot(2,7,i)
    ax.set_title('Plot title ' + str(i))


fig.set_facecolor('w')
plt.tight_layout()
plt.show()
